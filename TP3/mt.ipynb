# %% [markdown]
# # TP MT
# ---

# %%
L1= {w ∈ {1,0} | la cadena contiene una cantidad impar de 1 y termina en 0}

Origen      Destino     Lee     Escribe     Movimiento

q0          q1          1       1           R
q0          q0          0       0           R
q1          q0          1       1           R
q1          q1          0       0           R
q1          q2         blanco   blanco      L
q2          acc         0       0           S

# %%
L2= {a^n b^n c} | n>=1
"Misma cantidad de a que de b y una unica c al final"
Origen      Destino     Lee     Escribe     Movimiento

q0          q1          a       blanco      R
q1          q1          a       a           R
q1          q2          b       blanco      L
q2          q2          a       a           L
q2          q0          blanco  blanco      R      
q0          acc         case    case        S
